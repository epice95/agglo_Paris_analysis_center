# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Définition des fichiers DVF
folder_path = "C:/Users/NEZHA/OneDrive/Documents/EcoUrbaine_Project/Code/Inputs/DVF"
files = [
    "ValeursFoncieres-2019-S2.txt",
    "ValeursFoncieres-2020.txt",
    "ValeursFoncieres-2021.txt",
    "ValeursFoncieres-2022.txt",
    "ValeursFoncieres-2023.txt",
    "ValeursFoncieres-2024-S1.txt"
]

# Colonnes utiles
cols_to_keep = ["Date mutation", "Valeur fonciere", "Code postal", "Commune", "Surface reelle bati", "Type local"]

# Codes postaux pour Paris + Petite Couronne
codes_postaux = list(range(75000, 75021)) + list(range(92000, 92141)) + list(range(93000, 93211)) + list(range(94000, 94291))

# Lire et traiter les fichiers progressivement
df_list = []
chunksize = 50000  # Réduit l'impact mémoire

for file in files:
    file_path = os.path.join(folder_path, file)
    print(f"Traitement de {file}...")
    
    for chunk in pd.read_csv(file_path, delimiter='|', encoding='utf-8', usecols=cols_to_keep, chunksize=chunksize, low_memory=False):
        chunk = chunk[chunk["Code postal"].isin(codes_postaux)]  # Filtrage des départements concernés
        chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
        chunk["Année"] = chunk["Date mutation"].dt.year
        chunk["Valeur fonciere"] = pd.to_numeric(chunk["Valeur fonciere"].astype(str).str.replace(',', '.'), errors='coerce')
        chunk["Prix_m2"] = chunk["Valeur fonciere"] / chunk["Surface reelle bati"]
        chunk = chunk[chunk["Prix_m2"] < 30000]  # Suppression des valeurs aberrantes
        df_list.append(chunk[["Année", "Code postal", "Prix_m2"]])

# Fusion des données
df_final = pd.concat(df_list, ignore_index=True)

# Calcul du prix moyen par an et département
prix_moyen_par_annee = df_final.groupby(["Année", "Code postal"])["Prix_m2"].mean().unstack()

# Affichage du graphique
prix_moyen_par_annee.plot(figsize=(12, 6))
plt.xlabel("Année")
plt.ylabel("Prix moyen au m² (€)")
plt.title("Évolution du prix moyen au m² en Île-de-France (Paris + Petite Couronne)")
plt.legend(title="Code Postal")
plt.grid()
plt.show()

# Affichage des résultats
print(prix_moyen_par_annee)
# Out:
# Traitement de ValeursFoncieres-2019-S2.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2020.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2021.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2022.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2023.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2024-S1.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\3295920152.py:32: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Code postal       75001.0       75002.0       75003.0       75004.0  \
# Année
# 2019.0       12712.183034  10078.000621  11227.044400  12047.711323
# 2020.0       12066.331061  11235.456266  11887.135761  12668.750511
# 2021.0       12726.549990  11325.176633  11199.267270  12818.543352
# 2022.0       12412.979330  10793.003258  12107.833716  13424.200189
# 2023.0       12005.735486  11123.780827  10584.288607  12387.015283
# 2024.0       12142.994922  10938.617869  11553.584366  12339.811086
#
# Code postal       75005.0       75006.0       75007.0       75008.0  \
# Année
# 2019.0       11910.211538  13319.999386  12842.309844  10771.738066
# 2020.0       12179.244847  14194.932405  14082.744189  11864.915360
# 2021.0       12366.589557  14791.093114  13788.698620  12209.632799
# 2022.0       12653.000411  14279.066500  13653.331746  13069.709800
# 2023.0       12068.794340  14840.540563  14012.761738  11925.550011
# 2024.0       11572.228955  13917.212089  13552.765837  12744.022834
#
# Code postal       75009.0       75010.0  ...      94190.0      94200.0  \
# Année                                    ...
# 2019.0       10891.184470   9805.428568  ...  3627.606917  6510.662960
# 2020.0       11165.361289  10944.638556  ...  4794.240680  5783.740406
# 2021.0       11333.378768   9823.550427  ...  4320.661488  6026.675720
# 2022.0       11189.195989  10652.205568  ...  4218.648394  6665.557367
# 2023.0       10862.564385   9796.547368  ...  5845.383907  5964.685380
# 2024.0       10595.499778   8782.244516  ...  7229.233846  6161.765875
#
# Code postal      94210.0      94220.0      94230.0      94240.0      94250.0  \
# Année
# 2019.0       6126.958078  8302.551823  5562.846082  4517.562433  6515.433070
# 2020.0       7154.693421  8156.970988  5613.661305  4533.817632  6773.698234
# 2021.0       7538.693905  8403.999354  6457.461531  5158.940042  7605.784379
# 2022.0       7962.783642  8522.391329  6479.118136  5356.025849  7176.598917
# 2023.0       7481.984594  7432.943058  6310.845748  5600.378827  6906.721019
# 2024.0       6854.612108  7325.648659  4935.194565  5130.451920  6185.664738
#
# Code postal      94260.0      94270.0      94290.0
# Année
# 2019.0       4432.089069  5769.703608  4538.355374
# 2020.0       4016.807169  6288.054948  4789.077200
# 2021.0       4033.755966  6015.519204  4898.760053
# 2022.0       3936.137552  8584.064562  5179.687533
# 2023.0       3882.096560  6687.376860  5601.371867
# 2024.0       3555.023273  5971.064744  5484.385697
#
# [6 rows x 57 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Définition des fichiers DVF
folder_path = "C:/Users/NEZHA/OneDrive/Documents/EcoUrbaine_Project/Code/Inputs/DVF"
files = [
    "ValeursFoncieres-2019-S2.txt",
    "ValeursFoncieres-2020.txt",
    "ValeursFoncieres-2021.txt",
    "ValeursFoncieres-2022.txt",
    "ValeursFoncieres-2023.txt",
    "ValeursFoncieres-2024-S1.txt"
]

# Colonnes utiles
cols_to_keep = ["Date mutation", "Valeur fonciere", "Code postal", "Commune", "Surface reelle bati", "Type local"]

# Codes postaux pour Paris + Petite Couronne
codes_postaux = list(range(75000, 75021)) + list(range(92000, 92141)) + list(range(93000, 93211)) + list(range(94000, 94291))

# Associer les départements aux codes postaux
departements = {
    75: list(range(75000, 75021)),
    92: list(range(92000, 92141)),
    93: list(range(93000, 93211)),
    94: list(range(94000, 94291))
}

# Lire et traiter les fichiers progressivement
df_list = []
chunksize = 50000  # Réduit l'impact mémoire

for file in files:
    file_path = os.path.join(folder_path, file)
    print(f"Traitement de {file}...")
    
    for chunk in pd.read_csv(file_path, delimiter='|', encoding='utf-8', usecols=cols_to_keep, chunksize=chunksize, low_memory=False):
        chunk = chunk[chunk["Code postal"].isin(codes_postaux)]  # Filtrage des départements concernés
        chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
        chunk["Année"] = chunk["Date mutation"].dt.year
        chunk["Valeur fonciere"] = pd.to_numeric(chunk["Valeur fonciere"].astype(str).str.replace(',', '.'), errors='coerce')
        chunk["Prix_m2"] = chunk["Valeur fonciere"] / chunk["Surface reelle bati"]
        chunk = chunk[chunk["Prix_m2"] < 30000]  # Suppression des valeurs aberrantes
        
        # Ajouter une colonne département
        chunk["Département"] = chunk["Code postal"].apply(lambda x: next((dep for dep, codes in departements.items() if x in codes), None))
        
        df_list.append(chunk[["Année", "Code postal", "Département", "Prix_m2"]])

# Fusion des données
df_final = pd.concat(df_list, ignore_index=True)

# Calcul du prix moyen par an et département
prix_moyen_par_annee = df_final.groupby(["Année", "Code postal"])["Prix_m2"].mean().unstack()
prix_moyen_par_departement = df_final.groupby(["Année", "Département"])["Prix_m2"].mean().unstack()

# Affichage du premier graphique (par code postal)
prix_moyen_par_annee.plot(figsize=(12, 6))
plt.xlabel("Année")
plt.ylabel("Prix moyen au m² (€)")
plt.title("Évolution du prix moyen au m² en Île-de-France (Paris + Petite Couronne) par Code Postal")
plt.legend(title="Code Postal")
plt.grid()
plt.show()

# Affichage du deuxième graphique (par département)
prix_moyen_par_departement.plot(figsize=(12, 6))
plt.xlabel("Année")
plt.ylabel("Prix moyen au m² (€)")
plt.title("Évolution du prix moyen au m² en Île-de-France (Paris + Petite Couronne) par Département")
plt.legend(title="Département")
plt.grid()
plt.show()

# Affichage des résultats
print(prix_moyen_par_annee)
print(prix_moyen_par_departement)
# Out:
# Traitement de ValeursFoncieres-2019-S2.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2020.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2021.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2022.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2023.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2024-S1.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1885612910.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Code postal       75001.0       75002.0       75003.0       75004.0  \
# Année
# 2019.0       12712.183034  10078.000621  11227.044400  12047.711323
# 2020.0       12066.331061  11235.456266  11887.135761  12668.750511
# 2021.0       12726.549990  11325.176633  11199.267270  12818.543352
# 2022.0       12412.979330  10793.003258  12107.833716  13424.200189
# 2023.0       12005.735486  11123.780827  10584.288607  12387.015283
# 2024.0       12142.994922  10938.617869  11553.584366  12339.811086
#
# Code postal       75005.0       75006.0       75007.0       75008.0  \
# Année
# 2019.0       11910.211538  13319.999386  12842.309844  10771.738066
# 2020.0       12179.244847  14194.932405  14082.744189  11864.915360
# 2021.0       12366.589557  14791.093114  13788.698620  12209.632799
# 2022.0       12653.000411  14279.066500  13653.331746  13069.709800
# 2023.0       12068.794340  14840.540563  14012.761738  11925.550011
# 2024.0       11572.228955  13917.212089  13552.765837  12744.022834
#
# Code postal       75009.0       75010.0  ...      94190.0      94200.0  \
# Année                                    ...
# 2019.0       10891.184470   9805.428568  ...  3627.606917  6510.662960
# 2020.0       11165.361289  10944.638556  ...  4794.240680  5783.740406
# 2021.0       11333.378768   9823.550427  ...  4320.661488  6026.675720
# 2022.0       11189.195989  10652.205568  ...  4218.648394  6665.557367
# 2023.0       10862.564385   9796.547368  ...  5845.383907  5964.685380
# 2024.0       10595.499778   8782.244516  ...  7229.233846  6161.765875
#
# Code postal      94210.0      94220.0      94230.0      94240.0      94250.0  \
# Année
# 2019.0       6126.958078  8302.551823  5562.846082  4517.562433  6515.433070
# 2020.0       7154.693421  8156.970988  5613.661305  4533.817632  6773.698234
# 2021.0       7538.693905  8403.999354  6457.461531  5158.940042  7605.784379
# 2022.0       7962.783642  8522.391329  6479.118136  5356.025849  7176.598917
# 2023.0       7481.984594  7432.943058  6310.845748  5600.378827  6906.721019
# 2024.0       6854.612108  7325.648659  4935.194565  5130.451920  6185.664738
#
# Code postal      94260.0      94270.0      94290.0
# Année
# 2019.0       4432.089069  5769.703608  4538.355374
# 2020.0       4016.807169  6288.054948  4789.077200
# 2021.0       4033.755966  6015.519204  4898.760053
# 2022.0       3936.137552  8584.064562  5179.687533
# 2023.0       3882.096560  6687.376860  5601.371867
# 2024.0       3555.023273  5971.064744  5484.385697
#
# [6 rows x 57 columns]
# Département          75.0         92.0         93.0         94.0
# Année
# 2019.0       10349.872093  7424.432099  5174.561928  6085.972020
# 2020.0       10679.781409  8302.994446  5385.146343  6393.514799
# 2021.0       10865.618700  8404.054113  5353.628989  6614.557837
# 2022.0       11082.870378  8590.157351  5514.718705  6722.463471
# 2023.0       10413.308109  7940.595379  4930.537866  6496.386875
# 2024.0       10163.575292  7626.427231  6776.751368  6168.035254

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Définition des fichiers DVF
folder_path = "C:/Users/NEZHA/OneDrive/Documents/EcoUrbaine_Project/Code/Inputs/DVF"
files = [
    "ValeursFoncieres-2019-S2.txt",
    "ValeursFoncieres-2020.txt",
    "ValeursFoncieres-2021.txt",
    "ValeursFoncieres-2022.txt",
    "ValeursFoncieres-2023.txt",
    "ValeursFoncieres-2024-S1.txt"
]

# Colonnes utiles
cols_to_keep = ["Date mutation", "Valeur fonciere", "Code postal", "Commune", "Surface reelle bati", "Type local"]

# Codes postaux pour Paris + Petite Couronne
codes_postaux = list(range(75000, 75021)) + list(range(92000, 92141)) + list(range(93000, 93211)) + list(range(94000, 94291))

# Associer les départements aux codes postaux
departements = {
    75: list(range(75000, 75021)),
    92: list(range(92000, 92141)),
    93: list(range(93000, 93211)),
    94: list(range(94000, 94291))
}

# Lire et traiter les fichiers progressivement
df_list = []
chunksize = 50000  # Réduit l'impact mémoire

for file in files:
    file_path = os.path.join(folder_path, file)
    print(f"Traitement de {file}...")
    
    for chunk in pd.read_csv(file_path, delimiter='|', encoding='utf-8', usecols=cols_to_keep, chunksize=chunksize, low_memory=False):
        chunk = chunk[chunk["Code postal"].isin(codes_postaux)]  # Filtrage des départements concernés
        chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
        chunk["Année"] = chunk["Date mutation"].dt.year
        chunk["Valeur fonciere"] = pd.to_numeric(chunk["Valeur fonciere"].astype(str).str.replace(',', '.'), errors='coerce')
        chunk["Prix_m2"] = chunk["Valeur fonciere"] / chunk["Surface reelle bati"]
        chunk = chunk[chunk["Prix_m2"] < 30000]  # Suppression des valeurs aberrantes
        
        # Ajouter une colonne département
        chunk["Département"] = chunk["Code postal"].apply(lambda x: next((dep for dep, codes in departements.items() if x in codes), None))
        
        df_list.append(chunk[["Année", "Code postal", "Département", "Prix_m2"]])

# Fusion des données
df_final = pd.concat(df_list, ignore_index=True)

# Calcul du prix moyen par an et département
prix_moyen_par_annee = df_final.groupby(["Année", "Code postal"])["Prix_m2"].mean().unstack()
prix_moyen_par_departement = df_final.groupby(["Année", "Département"])["Prix_m2"].mean().unstack()

# Graphique par code postal
prix_moyen_par_annee.plot(figsize=(12, 6))
plt.xlabel("Année")
plt.ylabel("Prix moyen au m² (€)")
plt.title("Évolution du prix moyen au m² en Île-de-France (Paris + Petite Couronne) par Code Postal")
plt.legend(title="Code Postal")
plt.grid()
plt.show()

# Graphique par département
prix_moyen_par_departement.plot(figsize=(12, 6))
plt.xlabel("Année")
plt.ylabel("Prix moyen au m² (€)")
plt.title("Évolution du prix moyen au m² en Île-de-France (Paris + Petite Couronne) par Département")
plt.legend(title="Département")
plt.grid()
plt.show()

# Nuage de points (prix au m² par année)
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_final, x="Année", y="Prix_m2", alpha=0.5)
plt.xlabel("Année")
plt.ylabel("Prix au m² (€)")
plt.title("Distribution des prix au m² par année")
plt.grid()
plt.show()

# Régression linéaire des prix au m² par département
plt.figure(figsize=(12, 6))
sns.lmplot(data=df_final, x="Année", y="Prix_m2", hue="Département", aspect=1.5, scatter_kws={"alpha":0.3})
plt.xlabel("Année")
plt.ylabel("Prix au m² (€)")
plt.title("Régression linéaire des prix au m² par département")
plt.grid()
plt.show()

# Affichage des résultats
print(prix_moyen_par_annee)
print(prix_moyen_par_departement)
# Out:
# Traitement de ValeursFoncieres-2019-S2.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2020.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2021.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2022.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2023.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2024-S1.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\687048502.py:41: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Code postal       75001.0       75002.0       75003.0       75004.0  \
# Année
# 2019.0       12712.183034  10078.000621  11227.044400  12047.711323
# 2020.0       12066.331061  11235.456266  11887.135761  12668.750511
# 2021.0       12726.549990  11325.176633  11199.267270  12818.543352
# 2022.0       12412.979330  10793.003258  12107.833716  13424.200189
# 2023.0       12005.735486  11123.780827  10584.288607  12387.015283
# 2024.0       12142.994922  10938.617869  11553.584366  12339.811086
#
# Code postal       75005.0       75006.0       75007.0       75008.0  \
# Année
# 2019.0       11910.211538  13319.999386  12842.309844  10771.738066
# 2020.0       12179.244847  14194.932405  14082.744189  11864.915360
# 2021.0       12366.589557  14791.093114  13788.698620  12209.632799
# 2022.0       12653.000411  14279.066500  13653.331746  13069.709800
# 2023.0       12068.794340  14840.540563  14012.761738  11925.550011
# 2024.0       11572.228955  13917.212089  13552.765837  12744.022834
#
# Code postal       75009.0       75010.0  ...      94190.0      94200.0  \
# Année                                    ...
# 2019.0       10891.184470   9805.428568  ...  3627.606917  6510.662960
# 2020.0       11165.361289  10944.638556  ...  4794.240680  5783.740406
# 2021.0       11333.378768   9823.550427  ...  4320.661488  6026.675720
# 2022.0       11189.195989  10652.205568  ...  4218.648394  6665.557367
# 2023.0       10862.564385   9796.547368  ...  5845.383907  5964.685380
# 2024.0       10595.499778   8782.244516  ...  7229.233846  6161.765875
#
# Code postal      94210.0      94220.0      94230.0      94240.0      94250.0  \
# Année
# 2019.0       6126.958078  8302.551823  5562.846082  4517.562433  6515.433070
# 2020.0       7154.693421  8156.970988  5613.661305  4533.817632  6773.698234
# 2021.0       7538.693905  8403.999354  6457.461531  5158.940042  7605.784379
# 2022.0       7962.783642  8522.391329  6479.118136  5356.025849  7176.598917
# 2023.0       7481.984594  7432.943058  6310.845748  5600.378827  6906.721019
# 2024.0       6854.612108  7325.648659  4935.194565  5130.451920  6185.664738
#
# Code postal      94260.0      94270.0      94290.0
# Année
# 2019.0       4432.089069  5769.703608  4538.355374
# 2020.0       4016.807169  6288.054948  4789.077200
# 2021.0       4033.755966  6015.519204  4898.760053
# 2022.0       3936.137552  8584.064562  5179.687533
# 2023.0       3882.096560  6687.376860  5601.371867
# 2024.0       3555.023273  5971.064744  5484.385697
#
# [6 rows x 57 columns]
# Département          75.0         92.0         93.0         94.0
# Année
# 2019.0       10349.872093  7424.432099  5174.561928  6085.972020
# 2020.0       10679.781409  8302.994446  5385.146343  6393.514799
# 2021.0       10865.618700  8404.054113  5353.628989  6614.557837
# 2022.0       11082.870378  8590.157351  5514.718705  6722.463471
# 2023.0       10413.308109  7940.595379  4930.537866  6496.386875
# 2024.0       10163.575292  7626.427231  6776.751368  6168.035254

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
from sklearn.linear_model import LinearRegression

# Définition des fichiers DVF
folder_path = "C:/Users/NEZHA/OneDrive/Documents/EcoUrbaine_Project/Code/Inputs/DVF"
files = [
    "ValeursFoncieres-2019-S2.txt",
    "ValeursFoncieres-2020.txt",
    "ValeursFoncieres-2021.txt",
    "ValeursFoncieres-2022.txt",
    "ValeursFoncieres-2023.txt",
    "ValeursFoncieres-2024-S1.txt"
]

# Colonnes utiles
cols_to_keep = ["Date mutation", "Valeur fonciere", "Code postal", "Commune", "Surface reelle bati", "Type local"]

# Codes postaux pour Paris + Petite Couronne
codes_postaux = list(range(75000, 75021)) + list(range(92000, 92141)) + list(range(93000, 93211)) + list(range(94000, 94291))

# Associer les départements aux codes postaux
departements = {
    75: list(range(75000, 75021)),
    92: list(range(92000, 92141)),
    93: list(range(93000, 93211)),
    94: list(range(94000, 94291))
}

# Lire et traiter les fichiers progressivement
df_list = []
chunksize = 50000  # Réduit l'impact mémoire

for file in files:
    file_path = os.path.join(folder_path, file)
    print(f"Traitement de {file}...")
    
    for chunk in pd.read_csv(file_path, delimiter='|', encoding='utf-8', usecols=cols_to_keep, chunksize=chunksize, low_memory=False):
        chunk = chunk[chunk["Code postal"].isin(codes_postaux)]  # Filtrage des départements concernés
        chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
        chunk["Année"] = chunk["Date mutation"].dt.year
        chunk["Valeur fonciere"] = pd.to_numeric(chunk["Valeur fonciere"].astype(str).str.replace(',', '.'), errors='coerce')
        chunk["Prix_m2"] = chunk["Valeur fonciere"] / chunk["Surface reelle bati"]
        chunk = chunk[chunk["Prix_m2"] < 30000]  # Suppression des valeurs aberrantes
        
        # Ajouter une colonne département
        chunk["Département"] = chunk["Code postal"].apply(lambda x: next((dep for dep, codes in departements.items() if x in codes), None))
        
        df_list.append(chunk[["Année", "Code postal", "Département", "Prix_m2"]])

# Fusion des données
df_final = pd.concat(df_list, ignore_index=True)

# Calcul du prix moyen par an et département
prix_moyen_par_annee = df_final.groupby(["Année", "Code postal"])["Prix_m2"].mean().unstack()
prix_moyen_par_departement = df_final.groupby(["Année", "Département"])["Prix_m2"].mean().unstack()

# Graphique par code postal
prix_moyen_par_annee.plot(figsize=(12, 6))
plt.xlabel("Année")
plt.ylabel("Prix moyen au m² (€)")
plt.title("Évolution du prix moyen au m² en Île-de-France (Paris + Petite Couronne) par Code Postal")
plt.legend(title="Code Postal")
plt.grid()
plt.show()

# Graphique par département
prix_moyen_par_departement.plot(figsize=(12, 6))
plt.xlabel("Année")
plt.ylabel("Prix moyen au m² (€)")
plt.title("Évolution du prix moyen au m² en Île-de-France (Paris + Petite Couronne) par Département")
plt.legend(title="Département")
plt.grid()
plt.show()

# Nuage de points (prix au m² par année)
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_final, x="Année", y="Prix_m2", alpha=0.5)
plt.xlabel("Année")
plt.ylabel("Prix au m² (€)")
plt.title("Distribution des prix au m² par année")
plt.grid()
plt.show()

# Régression linéaire des prix au m² par département
plt.figure(figsize=(12, 6))
sns.lmplot(data=df_final, x="Année", y="Prix_m2", hue="Département", aspect=1.5, scatter_kws={"alpha":0.3})
plt.xlabel("Année")
plt.ylabel("Prix au m² (€)")
plt.title("Régression linéaire des prix au m² par département")
plt.grid()
plt.show()

# Prévision pour 2025
future_year = 2025
plt.figure(figsize=(12, 6))
for dep in prix_moyen_par_departement.columns:
    data = prix_moyen_par_departement[[dep]].dropna()
    X = data.index.values.reshape(-1, 1)
    y = data[dep].values
    model = LinearRegression()
    model.fit(X, y)
    prediction = model.predict([[future_year]])[0]
    plt.plot(data.index, y, marker='o', label=f"{dep}")
    plt.scatter(future_year, prediction, marker='x', color='red', s=100)
    print(f"Prévision pour {dep} en 2025: {prediction:.2f} €/m²")

plt.xlabel("Année")
plt.ylabel("Prix moyen au m² (€)")
plt.title("Prévision du prix moyen au m² en 2025 par département")
plt.legend(title="Département")
plt.grid()
plt.show()

# Affichage des résultats
print(prix_moyen_par_annee)
print(prix_moyen_par_departement)
# Out:
# Traitement de ValeursFoncieres-2019-S2.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2020.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2021.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2022.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2023.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2024-S1.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2783744328.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Prévision pour 75.0 en 2025: 10441.14 €/m²
# Prévision pour 92.0 en 2025: 8059.00 €/m²
# Prévision pour 93.0 en 2025: 6203.38 €/m²
# Prévision pour 94.0 en 2025: 6496.17 €/m²
# Code postal       75001.0       75002.0       75003.0       75004.0  \
# Année
# 2019.0       12712.183034  10078.000621  11227.044400  12047.711323
# 2020.0       12066.331061  11235.456266  11887.135761  12668.750511
# 2021.0       12726.549990  11325.176633  11199.267270  12818.543352
# 2022.0       12412.979330  10793.003258  12107.833716  13424.200189
# 2023.0       12005.735486  11123.780827  10584.288607  12387.015283
# 2024.0       12142.994922  10938.617869  11553.584366  12339.811086
#
# Code postal       75005.0       75006.0       75007.0       75008.0  \
# Année
# 2019.0       11910.211538  13319.999386  12842.309844  10771.738066
# 2020.0       12179.244847  14194.932405  14082.744189  11864.915360
# 2021.0       12366.589557  14791.093114  13788.698620  12209.632799
# 2022.0       12653.000411  14279.066500  13653.331746  13069.709800
# 2023.0       12068.794340  14840.540563  14012.761738  11925.550011
# 2024.0       11572.228955  13917.212089  13552.765837  12744.022834
#
# Code postal       75009.0       75010.0  ...      94190.0      94200.0  \
# Année                                    ...
# 2019.0       10891.184470   9805.428568  ...  3627.606917  6510.662960
# 2020.0       11165.361289  10944.638556  ...  4794.240680  5783.740406
# 2021.0       11333.378768   9823.550427  ...  4320.661488  6026.675720
# 2022.0       11189.195989  10652.205568  ...  4218.648394  6665.557367
# 2023.0       10862.564385   9796.547368  ...  5845.383907  5964.685380
# 2024.0       10595.499778   8782.244516  ...  7229.233846  6161.765875
#
# Code postal      94210.0      94220.0      94230.0      94240.0      94250.0  \
# Année
# 2019.0       6126.958078  8302.551823  5562.846082  4517.562433  6515.433070
# 2020.0       7154.693421  8156.970988  5613.661305  4533.817632  6773.698234
# 2021.0       7538.693905  8403.999354  6457.461531  5158.940042  7605.784379
# 2022.0       7962.783642  8522.391329  6479.118136  5356.025849  7176.598917
# 2023.0       7481.984594  7432.943058  6310.845748  5600.378827  6906.721019
# 2024.0       6854.612108  7325.648659  4935.194565  5130.451920  6185.664738
#
# Code postal      94260.0      94270.0      94290.0
# Année
# 2019.0       4432.089069  5769.703608  4538.355374
# 2020.0       4016.807169  6288.054948  4789.077200
# 2021.0       4033.755966  6015.519204  4898.760053
# 2022.0       3936.137552  8584.064562  5179.687533
# 2023.0       3882.096560  6687.376860  5601.371867
# 2024.0       3555.023273  5971.064744  5484.385697
#
# [6 rows x 57 columns]
# Département          75.0         92.0         93.0         94.0
# Année
# 2019.0       10349.872093  7424.432099  5174.561928  6085.972020
# 2020.0       10679.781409  8302.994446  5385.146343  6393.514799
# 2021.0       10865.618700  8404.054113  5353.628989  6614.557837
# 2022.0       11082.870378  8590.157351  5514.718705  6722.463471
# 2023.0       10413.308109  7940.595379  4930.537866  6496.386875
# 2024.0       10163.575292  7626.427231  6776.751368  6168.035254

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

# Définition des fichiers DVF
folder_path = "C:/Users/NEZHA/OneDrive/Documents/EcoUrbaine_Project/Code/Inputs/DVF"
files = [
    "ValeursFoncieres-2019-S2.txt",
    "ValeursFoncieres-2020.txt",
    "ValeursFoncieres-2021.txt",
    "ValeursFoncieres-2022.txt",
    "ValeursFoncieres-2023.txt",
    "ValeursFoncieres-2024-S1.txt"
]

# Colonnes utiles
cols_to_keep = ["Date mutation", "Valeur fonciere", "Code postal", "Commune", "Surface reelle bati", "Type local"]

# Codes postaux pour Paris + Petite Couronne
codes_postaux = list(range(75000, 75021)) + list(range(92000, 92141)) + list(range(93000, 93211)) + list(range(94000, 94291))

# Associer les départements aux codes postaux
departements = {
    75: list(range(75000, 75021)),
    92: list(range(92000, 92141)),
    93: list(range(93000, 93211)),
    94: list(range(94000, 94291))
}

# Lire et traiter les fichiers progressivement
df_list = []
chunksize = 50000  # Réduit l'impact mémoire

for file in files:
    file_path = os.path.join(folder_path, file)
    print(f"Traitement de {file}...")
    
    for chunk in pd.read_csv(file_path, delimiter='|', encoding='utf-8', usecols=cols_to_keep, chunksize=chunksize, low_memory=False):
        chunk = chunk[chunk["Code postal"].isin(codes_postaux)]  # Filtrage des départements concernés
        chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
        chunk["Année"] = chunk["Date mutation"].dt.year
        chunk["Valeur fonciere"] = pd.to_numeric(chunk["Valeur fonciere"].astype(str).str.replace(',', '.'), errors='coerce')
        chunk["Prix_m2"] = chunk["Valeur fonciere"] / chunk["Surface reelle bati"]
        chunk = chunk[chunk["Prix_m2"] < 30000]  # Suppression des valeurs aberrantes
        
        # Ajouter une colonne département
        chunk["Département"] = chunk["Code postal"].apply(lambda x: next((dep for dep, codes in departements.items() if x in codes), None))
        
        df_list.append(chunk[["Année", "Code postal", "Département", "Prix_m2", "Surface reelle bati", "Type local"]])

# Fusion des données
df_final = pd.concat(df_list, ignore_index=True)

# Calcul du prix moyen par an et département
prix_moyen_par_annee = df_final.groupby(["Année", "Code postal"])["Prix_m2"].mean().unstack()
prix_moyen_par_departement = df_final.groupby(["Année", "Département"])["Prix_m2"].mean().unstack()

# Graphique par code postal
prix_moyen_par_annee.plot(figsize=(12, 6))
plt.xlabel("Année")
plt.ylabel("Prix moyen au m² (€)")
plt.title("Évolution du prix moyen au m² en Île-de-France (Paris + Petite Couronne) par Code Postal")
plt.legend(title="Code Postal")
plt.grid()
plt.show()

# Graphique par département
prix_moyen_par_departement.plot(figsize=(12, 6))
plt.xlabel("Année")
plt.ylabel("Prix moyen au m² (€)")
plt.title("Évolution du prix moyen au m² en Île-de-France (Paris + Petite Couronne) par Département")
plt.legend(title="Département")
plt.grid()
plt.show()

# Nuage de points (prix au m² par année)
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_final, x="Année", y="Prix_m2", alpha=0.5)
plt.xlabel("Année")
plt.ylabel("Prix au m² (€)")
plt.title("Distribution des prix au m² par année")
plt.grid()
plt.show()

# Régression linéaire des prix au m² par département
plt.figure(figsize=(12, 6))
sns.lmplot(data=df_final, x="Année", y="Prix_m2", hue="Département", aspect=1.5, scatter_kws={"alpha":0.3})
plt.xlabel("Année")
plt.ylabel("Prix au m² (€)")
plt.title("Régression linéaire des prix au m² par département")
plt.grid()
plt.show()

# Boxplot des prix au m² par département
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_final, x="Département", y="Prix_m2")
plt.xlabel("Département")
plt.ylabel("Prix au m² (€)")
plt.title("Répartition des prix au m² par département")
plt.grid()
plt.show()

# Histogramme des prix au m²
plt.figure(figsize=(12, 6))
df_final["Prix_m2"].hist(bins=100, alpha=0.7)
plt.xlabel("Prix au m² (€)")
plt.ylabel("Nombre de transactions")
plt.title("Distribution des prix au m²")
plt.grid()
plt.show()

# Comparaison des prix entre appartements et maisons
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_final, x="Type local", y="Prix_m2")
plt.xlabel("Type de bien")
plt.ylabel("Prix au m² (€)")
plt.title("Comparaison des prix au m² entre appartements et maisons")
plt.grid()
plt.show()

# Scatter plot prix au m² vs surface
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_final, x="Surface reelle bati", y="Prix_m2", alpha=0.3)
plt.xlabel("Surface réelle bâtie (m²)")
plt.ylabel("Prix au m² (€)")
plt.title("Relation entre la surface et le prix au m²")
plt.grid()
plt.show()

# Ratio transactions haut de gamme (>10 000€/m²) vs standard
high_end_ratio = (df_final["Prix_m2"] > 10000).sum() / len(df_final)
print(f"Ratio de transactions haut de gamme (>10 000€/m²) : {high_end_ratio:.2%}")
# Out:
# Traitement de ValeursFoncieres-2019-S2.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2020.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2021.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2022.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2023.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2024-S1.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\255917924.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Ratio de transactions haut de gamme (>10 000€/m²) : 38.43%

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

# Définition des fichiers DVF
folder_path = "C:/Users/NEZHA/OneDrive/Documents/EcoUrbaine_Project/Code/Inputs/DVF"
files = [
    "ValeursFoncieres-2019-S2.txt",
    "ValeursFoncieres-2020.txt",
    "ValeursFoncieres-2021.txt",
    "ValeursFoncieres-2022.txt",
    "ValeursFoncieres-2023.txt",
    "ValeursFoncieres-2024-S1.txt"
]

# Colonnes utiles
cols_to_keep = ["Date mutation", "Valeur fonciere", "Code postal", "Commune", "Surface reelle bati", "Type local"]

# Codes postaux pour Paris + Petite Couronne
codes_postaux = list(range(75000, 75021)) + list(range(92000, 92141)) + list(range(93000, 93211)) + list(range(94000, 94291))

# Associer les départements aux codes postaux
departements = {
    75: list(range(75000, 75021)),
    92: list(range(92000, 92141)),
    93: list(range(93000, 93211)),
    94: list(range(94000, 94291))
}

# Lire et traiter les fichiers progressivement
df_list = []
chunksize = 50000  # Réduit l'impact mémoire

for file in files:
    file_path = os.path.join(folder_path, file)
    print(f"Traitement de {file}...")
    
    for chunk in pd.read_csv(file_path, delimiter='|', encoding='utf-8', usecols=cols_to_keep, chunksize=chunksize, low_memory=False):
        chunk = chunk[chunk["Code postal"].isin(codes_postaux)]  # Filtrage des départements concernés
        chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
        chunk["Année"] = chunk["Date mutation"].dt.year
        chunk["Valeur fonciere"] = pd.to_numeric(chunk["Valeur fonciere"].astype(str).str.replace(',', '.'), errors='coerce')
        chunk["Prix_m2"] = chunk["Valeur fonciere"] / chunk["Surface reelle bati"]
        chunk = chunk[chunk["Prix_m2"] < 30000]  # Suppression des valeurs aberrantes
        
        # Ajouter une colonne département
        chunk["Département"] = chunk["Code postal"].apply(lambda x: next((dep for dep, codes in departements.items() if x in codes), None))
        
        df_list.append(chunk[["Année", "Code postal", "Département", "Prix_m2", "Surface reelle bati", "Type local"]])

# Fusion des données
df_final = pd.concat(df_list, ignore_index=True)

# Boxplot des prix au m² par département
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_final, x="Département", y="Prix_m2")
plt.xlabel("Département")
plt.ylabel("Prix au m² (€)")
plt.title("Répartition des prix au m² par département")
plt.grid()
plt.show()

# Histogramme des prix au m²
plt.figure(figsize=(12, 6))
df_final["Prix_m2"].hist(bins=100, alpha=0.7)
plt.xlabel("Prix au m² (€)")
plt.ylabel("Nombre de transactions")
plt.title("Distribution des prix au m²")
plt.grid()
plt.show()

# Comparaison des prix entre appartements et maisons
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_final, x="Type local", y="Prix_m2")
plt.xlabel("Type de bien")
plt.ylabel("Prix au m² (€)")
plt.title("Comparaison des prix au m² entre appartements et maisons")
plt.grid()
plt.show()

# Scatter plot prix au m² vs surface
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_final, x="Surface reelle bati", y="Prix_m2", alpha=0.3)
plt.xlabel("Surface réelle bâtie (m²)")
plt.ylabel("Prix au m² (€)")
plt.title("Relation entre la surface et le prix au m²")
plt.grid()
plt.show()

# Ratio transactions haut de gamme (>10 000€/m²) vs standard
high_end_ratio = (df_final["Prix_m2"] > 10000).sum() / len(df_final)
print(f"Ratio de transactions haut de gamme (>10 000€/m²) : {high_end_ratio:.2%}")
# Out:
# Traitement de ValeursFoncieres-2019-S2.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2020.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2021.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2022.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2023.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2024-S1.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1727280477.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Ratio de transactions haut de gamme (>10 000€/m²) : 38.43%

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
from sklearn.linear_model import LinearRegression

# Définition des fichiers DVF
folder_path = "C:/Users/NEZHA/OneDrive/Documents/EcoUrbaine_Project/Code/Inputs/DVF"
files = [
    "ValeursFoncieres-2019-S2.txt",
    "ValeursFoncieres-2020.txt",
    "ValeursFoncieres-2021.txt",
    "ValeursFoncieres-2022.txt",
    "ValeursFoncieres-2023.txt",
    "ValeursFoncieres-2024-S1.txt"
]

# Colonnes utiles
cols_to_keep = ["Date mutation", "Valeur fonciere", "Code postal", "Commune", "Surface reelle bati", "Type local"]

# Codes postaux pour Paris + Petite Couronne
codes_postaux = list(range(75000, 75021)) + list(range(92000, 92141)) + list(range(93000, 93211)) + list(range(94000, 94291))

# Associer les départements aux codes postaux
departements = {
    75: list(range(75000, 75021)),
    92: list(range(92000, 92141)),
    93: list(range(93000, 93211)),
    94: list(range(94000, 94291))
}

# Lire et traiter les fichiers progressivement
df_list = []
chunksize = 50000  # Réduit l'impact mémoire

for file in files:
    file_path = os.path.join(folder_path, file)
    print(f"Traitement de {file}...")
    
    for chunk in pd.read_csv(file_path, delimiter='|', encoding='utf-8', usecols=cols_to_keep, chunksize=chunksize, low_memory=False):
        chunk = chunk[chunk["Code postal"].isin(codes_postaux)]  # Filtrage des départements concernés
        chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
        chunk["Année"] = chunk["Date mutation"].dt.year
        chunk["Valeur fonciere"] = pd.to_numeric(chunk["Valeur fonciere"].astype(str).str.replace(',', '.'), errors='coerce')
        chunk["Prix_m2"] = chunk["Valeur fonciere"] / chunk["Surface reelle bati"]
        chunk = chunk[chunk["Prix_m2"] < 30000]  # Suppression des valeurs aberrantes
        
        # Ajouter une colonne département
        chunk["Département"] = chunk["Code postal"].apply(lambda x: next((dep for dep, codes in departements.items() if x in codes), None))
        
        df_list.append(chunk[["Année", "Code postal", "Département", "Prix_m2", "Surface reelle bati", "Type local"]])

# Fusion des données
df_final = pd.concat(df_list, ignore_index=True)

# Moyenne des prix par année et département
prix_par_annee = df_final.groupby(["Année", "Département"]).Prix_m2.mean().unstack()

# Régression linéaire pour prédire 2025
X = np.array(prix_par_annee.index).reshape(-1, 1)
y_pred = {}

plt.figure(figsize=(12, 6))
for dep in [75, 92, 93, 94]:
    y = prix_par_annee[dep].values.reshape(-1, 1)
    model = LinearRegression()
    model.fit(X, y)
    future_year = np.array([[2025]])
    y_pred[dep] = model.predict(future_year)[0][0]
    
    plt.plot(prix_par_annee.index, y, marker='o', linestyle='-', label=f"Département {dep}")
    plt.plot([2025], y_pred[dep], marker='x', markersize=10, color='red')
    
plt.xlabel("Année")
plt.ylabel("Prix moyen au m² (€)")
plt.title("Prévision des prix au m² en 2025 par département")
plt.legend()
plt.grid()
plt.show()

# Affichage du tableau de régression linéaire
regression_df = pd.DataFrame(y_pred.items(), columns=["Département", "Prévision Prix_m2 en 2025"])
print(regression_df)
# Out:
# Traitement de ValeursFoncieres-2019-S2.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2020.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2021.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2022.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2023.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2024-S1.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\2723507921.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
#    Département  Prévision Prix_m2 en 2025
# 0           75               10441.139108
# 1           92                8058.998273
# 2           93                6203.378682
# 3           94                6496.172179

# %%
import pandas as pd
import os
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# Définition des fichiers DVF
folder_path = "C:/Users/NEZHA/OneDrive/Documents/EcoUrbaine_Project/Code/Inputs/DVF"
files = [
    "ValeursFoncieres-2019-S2.txt",
    "ValeursFoncieres-2020.txt",
    "ValeursFoncieres-2021.txt",
    "ValeursFoncieres-2022.txt",
    "ValeursFoncieres-2023.txt",
    "ValeursFoncieres-2024-S1.txt"
]

# Colonnes utiles
cols_to_keep = ["Date mutation", "Valeur fonciere", "Code postal", "Commune", "Surface reelle bati", "Type local"]

# Codes postaux pour Paris + Petite Couronne
codes_postaux = list(range(75000, 75021)) + list(range(92000, 92141)) + list(range(93000, 93211)) + list(range(94000, 94291))

# Associer les départements aux codes postaux
departements = {
    75: list(range(75000, 75021)),
    92: list(range(92000, 92141)),
    93: list(range(93000, 93211)),
    94: list(range(94000, 94291))
}

# Lire et traiter les fichiers progressivement
df_list = []
chunksize = 50000  # Réduit l'impact mémoire

for file in files:
    file_path = os.path.join(folder_path, file)
    print(f"Traitement de {file}...")
    
    for chunk in pd.read_csv(file_path, delimiter='|', encoding='utf-8', usecols=cols_to_keep, chunksize=chunksize, low_memory=False):
        chunk = chunk[chunk["Code postal"].isin(codes_postaux)]  # Filtrage des départements concernés
        chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
        chunk["Année"] = chunk["Date mutation"].dt.year
        chunk["Valeur fonciere"] = pd.to_numeric(chunk["Valeur fonciere"].astype(str).str.replace(',', '.'), errors='coerce')
        chunk["Prix_m2"] = chunk["Valeur fonciere"] / chunk["Surface reelle bati"]
        chunk = chunk[chunk["Prix_m2"] < 30000]  # Suppression des valeurs aberrantes
        
        # Ajouter une colonne département
        chunk["Département"] = chunk["Code postal"].apply(lambda x: next((dep for dep, codes in departements.items() if x in codes), None))
        
        df_list.append(chunk[["Année", "Code postal", "Département", "Prix_m2", "Surface reelle bati", "Type local"]])

# Fusion des données
df_final = pd.concat(df_list, ignore_index=True)

# Moyenne des prix par année et département
prix_par_annee = df_final.groupby(["Année", "Département"]).Prix_m2.mean().unstack()

# Régression linéaire pour prédire 2025
X = np.array(prix_par_annee.index).reshape(-1, 1)
y_pred = {}
regression_results = []

for dep in [75, 92, 93, 94]:
    y = prix_par_annee[dep].values.reshape(-1, 1)
    model = LinearRegression()
    model.fit(X, y)
    future_year = np.array([[2025]])
    y_pred[dep] = model.predict(future_year)[0][0]
    
    # Création du tableau de régression linéaire
    X_sm = sm.add_constant(X)  # Ajout d'une constante pour statsmodels
    model_sm = sm.OLS(y, X_sm).fit()
    summary_df = pd.DataFrame(model_sm.summary2().tables[1])
    summary_df.insert(0, "Département", dep)
    regression_results.append(summary_df)

# Concaténer tous les résultats en un seul tableau
tableau_regression = pd.concat(regression_results, ignore_index=True)
print(tableau_regression)
# Out:
# Traitement de ValeursFoncieres-2019-S2.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2020.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2021.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2022.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2023.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2024-S1.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\4216767274.py:42: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
#    Département          Coef.       Std.Err.         t     P>|t|  \
# 0           75   98016.731982  181597.642902  0.539747  0.618016
# 1           75     -43.247206      89.833083 -0.481417  0.655372
# 2           92    1759.414262  249187.305744  0.007061  0.994705
# 3           92       3.110906     123.268472  0.025237  0.981075
# 4           93 -387700.285882  288920.351498 -1.341893  0.250741
# 5           93     194.520328     142.923694  1.361008  0.245142
# 6           94  -41342.313924  132539.564455 -0.311924  0.770681
# 7           94      23.623944      65.564936  0.360314  0.736833
#
#          [0.025         0.975]
# 0 -4.061792e+05  602212.618731
# 1 -2.926638e+02     206.169418
# 2 -6.900955e+05  693614.289572
# 3 -3.391372e+02     345.359052
# 4 -1.189872e+06  414471.209827
# 5 -2.022995e+02     591.340120
# 6 -4.093311e+05  326646.511052
# 7 -1.584135e+02     205.661388
# C:\Users\NEZHA\OneDrive\Documents\ANACONDA_\Lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\Users\NEZHA\OneDrive\Documents\ANACONDA_\Lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\Users\NEZHA\OneDrive\Documents\ANACONDA_\Lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\Users\NEZHA\OneDrive\Documents\ANACONDA_\Lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
import pandas as pd
import os
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns

# Définition des fichiers DVF
folder_path = "C:/Users/NEZHA/OneDrive/Documents/EcoUrbaine_Project/Code/Inputs/DVF"
files = [
    "ValeursFoncieres-2019-S2.txt",
    "ValeursFoncieres-2020.txt",
    "ValeursFoncieres-2021.txt",
    "ValeursFoncieres-2022.txt",
    "ValeursFoncieres-2023.txt",
    "ValeursFoncieres-2024-S1.txt"
]

# Colonnes utiles
cols_to_keep = ["Date mutation", "Valeur fonciere", "Code postal", "Commune", "Surface reelle bati", "Type local"]

# Codes postaux pour Paris + Petite Couronne
codes_postaux = list(range(75000, 75021)) + list(range(92000, 92141)) + list(range(93000, 93211)) + list(range(94000, 94291))

# Associer les départements aux codes postaux
departements = {
    75: list(range(75000, 75021)),
    92: list(range(92000, 92141)),
    93: list(range(93000, 93211)),
    94: list(range(94000, 94291))
}

# Lire et traiter les fichiers progressivement
df_list = []
chunksize = 50000  # Réduit l'impact mémoire

for file in files:
    file_path = os.path.join(folder_path, file)
    print(f"Traitement de {file}...")
    
    for chunk in pd.read_csv(file_path, delimiter='|', encoding='utf-8', usecols=cols_to_keep, chunksize=chunksize, low_memory=False):
        chunk = chunk[chunk["Code postal"].isin(codes_postaux)]  # Filtrage des départements concernés
        chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
        chunk["Année"] = chunk["Date mutation"].dt.year
        chunk["Valeur fonciere"] = pd.to_numeric(chunk["Valeur fonciere"].astype(str).str.replace(',', '.'), errors='coerce')
        chunk["Prix_m2"] = chunk["Valeur fonciere"] / chunk["Surface reelle bati"]
        chunk = chunk[chunk["Prix_m2"] < 30000]  # Suppression des valeurs aberrantes
        
        # Ajouter une colonne département
        chunk["Département"] = chunk["Code postal"].apply(lambda x: next((dep for dep, codes in departements.items() if x in codes), None))
        
        df_list.append(chunk[["Année", "Code postal", "Département", "Prix_m2", "Surface reelle bati", "Type local"]])

# Fusion des données
df_final = pd.concat(df_list, ignore_index=True)

# Moyenne des prix par année et département
prix_par_annee = df_final.groupby(["Année", "Département"]).Prix_m2.mean().unstack()

# Graphique 1 : Boxplot des prix au m² par département
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_final["Département"], y=df_final["Prix_m2"])
plt.title("Distribution des prix au m² par département")
plt.xlabel("Département")
plt.ylabel("Prix au m² (€)")
plt.show()

# Graphique 2 : Nuage de points année vs prix moyen au m²
plt.figure(figsize=(10, 6))
for dep in [75, 92, 93, 94]:
    sns.scatterplot(x=prix_par_annee.index, y=prix_par_annee[dep], label=f"Département {dep}")
plt.title("Évolution des prix au m² par département")
plt.xlabel("Année")
plt.ylabel("Prix au m² (€)")
plt.legend()
plt.show()

# Graphique 3 : Heatmap de corrélation
corr_matrix = df_final[["Prix_m2", "Surface reelle bati"]].corr()
plt.figure(figsize=(8, 5))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matrice de corrélation entre les variables")
plt.show()
# Out:
# Traitement de ValeursFoncieres-2019-S2.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2020.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2021.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2022.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2023.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# Traitement de ValeursFoncieres-2024-S1.txt...
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
# C:\Users\NEZHA\AppData\Local\Temp\ipykernel_10848\1030507745.py:43: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   chunk["Date mutation"] = pd.to_datetime(chunk["Date mutation"], errors='coerce')
